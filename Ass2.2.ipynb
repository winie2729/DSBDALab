# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv("/content/StudentsPerformance2.csv")

# %%
df
# Out:
#     Sr No Gender  Math_Score   Reading_Score  Writing_Score  Placement_Score  \
# 0       1      M          10              78             20               60
# 1       2      F          64              85             69               96
# 2       3      M          73              77             66               84
# 3       4      F          80              85             62               79
# 4       5      F          61              80             63               84
# 5       6      M          99              90             80              101
# 6       7      M          66              82             64               94
# 7       8      F          64              84             65               88
# 8       9      M          66              75             68               92
# 9      10      F          65              83             70               75
# 10     11      F          61              85             64               78
# ...

# %%
df.isnull()
# Out:
#     Sr No  Gender  Math_Score   Reading_Score  Writing_Score  Placement_Score  \
# 0   False   False        True           False           True            False
# 1   False   False       False           False          False            False
# 2   False   False       False           False          False            False
# 3   False   False       False           False          False            False
# 4   False   False       False           False          False            False
# 5   False   False       False           False          False            False
# 6   False   False       False           False          False            False
# 7   False   False       False           False          False            False
# 8   False   False       False           False          False            False
# 9   False   False       False           False          False            False
# 10  False   False       False           False          False            False
# ...

# %%
s = pd.isnull(df["Math_Score"])

# %%
df[s]
# Out:
# Empty DataFrame
# Columns: [Sr No, Gender, Math_Score,  Reading_Score, Writing_Score, Placement_Score, Club_Join_Date, placement offer letter, Region]
# Index: []

# %%
s1 = pd.notnull(df["Math_Score"])

# %%
df[s1]
# Out:
#     Sr No Gender  Math_Score   Reading_Score  Writing_Score  Placement_Score  \
# 1       2      F        64.0              85           69.0               96
# 2       3      M        73.0              77           66.0               84
# 3       4      F        80.0              85           62.0               79
# 4       5      F        61.0              80           63.0               84
# 5       6      M        99.0              90           80.0              101
# 6       7      M        66.0              82           64.0               94
# 7       8      F        64.0              84           65.0               88
# 8       9      M        66.0              75           68.0               92
# 9      10      F        65.0              83           70.0               75
# 10     11      F        61.0              85           64.0               78
# 11     12      M        78.0              89           70.0               92
# ...

# %%
s2 = pd.notnull(df["Region"])

# %%
s2
# Out:
# 0     True
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# 10    True
# 11    True
# 12    True
# 13    True
# 14    True
# 15    True
# 16    True
# 17    True
# 18    True
# 19    True
# 20    True
# 21    True
# 22    True
# 23    True
# 24    True
# 25    True
# 26    True
# 27    True
# 28    True
# 29    True
# Name: Region, dtype: bool

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['Gender'] = le.fit_transform(df['Gender'])
newdf=df

# %%
df
# Out:
#     Sr No  Gender  Math_Score   Reading_Score  Writing_Score  Placement_Score  \
# 0       1       1         NaN              78            NaN               60
# 1       2       0        64.0              85           69.0               96
# 2       3       1        73.0              77           66.0               84
# 3       4       0        80.0              85           62.0               79
# 4       5       0        61.0              80           63.0               84
# 5       6       1        99.0              90           80.0              101
# 6       7       1        66.0              82           64.0               94
# 7       8       0        64.0              84           65.0               88
# 8       9       1        66.0              75           68.0               92
# 9      10       0        65.0              83           70.0               75
# 10     11       0        61.0              85           64.0               78
# ...

# %%
missing_values = ["Na", "na"]
df = pd.read_csv("/content/StudentsPerformance2.csv", na_values =
missing_values)
df
# Out:
#     Sr No Gender  Math_Score   Reading_Score  Writing_Score  Placement_Score  \
# 0       1      M         NaN              78            NaN               60
# 1       2      F        64.0              85           69.0               96
# 2       3      M        73.0              77           66.0               84
# 3       4      F        80.0              85           62.0               79
# 4       5      F        61.0              80           63.0               84
# 5       6      M        99.0              90           80.0              101
# 6       7      M        66.0              82           64.0               94
# 7       8      F        64.0              84           65.0               88
# 8       9      M        66.0              75           68.0               92
# 9      10      F        65.0              83           70.0               75
# 10     11      F        61.0              85           64.0               78
# ...

# %%
ndf=df
ndf.fillna(0)
# Out:
#     Sr No Gender  Math_Score   Reading_Score  Writing_Score  Placement_Score  \
# 0       1      M         0.0              78            0.0               60
# 1       2      F        64.0              85           69.0               96
# 2       3      M        73.0              77           66.0               84
# 3       4      F        80.0              85           62.0               79
# 4       5      F        61.0              80           63.0               84
# 5       6      M        99.0              90           80.0              101
# 6       7      M        66.0              82           64.0               94
# 7       8      F        64.0              84           65.0               88
# 8       9      M        66.0              75           68.0               92
# 9      10      F        65.0              83           70.0               75
# 10     11      F        61.0              85           64.0               78
# ...

# %%
df['Math_Score'] = df['Math_Score'].fillna(df['Math_Score'].mean())

# %%
df
# Out:
#     Sr No Gender  Math_Score   Reading_Score  Writing_Score  Placement_Score  \
# 0       1      M   70.344828              78            NaN               60
# 1       2      F   64.000000              85           69.0               96
# 2       3      M   73.000000              77           66.0               84
# 3       4      F   80.000000              85           62.0               79
# 4       5      F   61.000000              80           63.0               84
# 5       6      M   99.000000              90           80.0              101
# 6       7      M   66.000000              82           64.0               94
# 7       8      F   64.000000              84           65.0               88
# 8       9      M   66.000000              75           68.0               92
# 9      10      F   65.000000              83           70.0               75
# 10     11      F   61.000000              85           64.0               78
# ...

# %%
df['Math_Score'] = df['Math_Score'].fillna(df['Math_Score'].median())
df
# Out:
#     Sr No Gender  Math_Score   Reading_Score  Writing_Score  Placement_Score  \
# 0       1      M   70.344828              78            NaN               60
# 1       2      F   64.000000              85           69.0               96
# 2       3      M   73.000000              77           66.0               84
# 3       4      F   80.000000              85           62.0               79
# 4       5      F   61.000000              80           63.0               84
# 5       6      M   99.000000              90           80.0              101
# 6       7      M   66.000000              82           64.0               94
# 7       8      F   64.000000              84           65.0               88
# 8       9      M   66.000000              75           68.0               92
# 9      10      F   65.000000              83           70.0               75
# 10     11      F   61.000000              85           64.0               78
# ...

# %%
df['Math_Score'] = df['Math_Score'].fillna(df['Math_Score'].std())
df
# Out:
#     Sr No Gender  Math_Score   Reading_Score  Writing_Score  Placement_Score  \
# 0       1      M   70.344828              78            NaN               60
# 1       2      F   64.000000              85           69.0               96
# 2       3      M   73.000000              77           66.0               84
# 3       4      F   80.000000              85           62.0               79
# 4       5      F   61.000000              80           63.0               84
# 5       6      M   99.000000              90           80.0              101
# 6       7      M   66.000000              82           64.0               94
# 7       8      F   64.000000              84           65.0               88
# 8       9      M   66.000000              75           68.0               92
# 9      10      F   65.000000              83           70.0               75
# 10     11      F   61.000000              85           64.0               78
# ...

# %%
columns_to_fill = ['Math_Score', 'Writing_Score']
df[columns_to_fill] = df[columns_to_fill].fillna(df[columns_to_fill].mean())
df
# Out:
#     Sr No Gender  Math_Score   Reading_Score  Writing_Score  Placement_Score  \
# 0       1      M   70.344828              78      65.689655               60
# 1       2      F   64.000000              85      69.000000               96
# 2       3      M   73.000000              77      66.000000               84
# 3       4      F   80.000000              85      62.000000               79
# 4       5      F   61.000000              80      63.000000               84
# 5       6      M   99.000000              90      80.000000              101
# 6       7      M   66.000000              82      64.000000               94
# 7       8      F   64.000000              84      65.000000               88
# 8       9      M   66.000000              75      68.000000               92
# 9      10      F   65.000000              83      70.000000               75
# 10     11      F   61.000000              85      64.000000               78
# ...

# %%
df.replace(to_replace = np.nan, value = -99)
# Out:
#     Sr No Gender  Math_Score   Reading_Score  Writing_Score  Placement_Score  \
# 0       1      M   70.344828              78      65.689655               60
# 1       2      F   64.000000              85      69.000000               96
# 2       3      M   73.000000              77      66.000000               84
# 3       4      F   80.000000              85      62.000000               79
# 4       5      F   61.000000              80      63.000000               84
# 5       6      M   99.000000              90      80.000000              101
# 6       7      M   66.000000              82      64.000000               94
# 7       8      F   64.000000              84      65.000000               88
# 8       9      M   66.000000              75      68.000000               92
# 9      10      F   65.000000              83      70.000000               75
# 10     11      F   61.000000              85      64.000000               78
# ...

# %%
#Deleting null values using dropna() method

# %%
import pandas as pd
import numpy as np
df2=pd.read_csv("/content/StudentsPerformance2.csv")
df2
# Out:
#     Sr No Gender  Math_Score   Reading_Score  Writing_Score  Placement_Score  \
# 0       1      M         NaN              78            NaN               60
# 1       2      F        64.0              85           69.0               96
# 2       3      M        73.0              77           66.0               84
# 3       4      F        80.0              85           62.0               79
# 4       5      F        61.0              80           63.0               84
# 5       6      M        99.0              90           80.0              101
# 6       7      M        66.0              82           64.0               94
# 7       8      F        64.0              84           65.0               88
# 8       9      M        66.0              75           68.0               92
# 9      10      F        65.0              83           70.0               75
# 10     11      F        61.0              85           64.0               78
# ...

# %%
df2.dropna()
# Out:
#     Sr No Gender  Math_Score   Reading_Score  Writing_Score  Placement_Score  \
# 1       2      F        64.0              85           69.0               96
# 2       3      M        73.0              77           66.0               84
# 3       4      F        80.0              85           62.0               79
# 4       5      F        61.0              80           63.0               84
# 5       6      M        99.0              90           80.0              101
# 6       7      M        66.0              82           64.0               94
# 7       8      F        64.0              84           65.0               88
# 8       9      M        66.0              75           68.0               92
# 9      10      F        65.0              83           70.0               75
# 10     11      F        61.0              85           64.0               78
# 11     12      M        78.0              89           70.0               92
# ...

# %%
df2.dropna(how = 'all')
# Out:
#     Sr No Gender  Math_Score   Reading_Score  Writing_Score  Placement_Score  \
# 0       1      M         NaN              78            NaN               60
# 1       2      F        64.0              85           69.0               96
# 2       3      M        73.0              77           66.0               84
# 3       4      F        80.0              85           62.0               79
# 4       5      F        61.0              80           63.0               84
# 5       6      M        99.0              90           80.0              101
# 6       7      M        66.0              82           64.0               94
# 7       8      F        64.0              84           65.0               88
# 8       9      M        66.0              75           68.0               92
# 9      10      F        65.0              83           70.0               75
# 10     11      F        61.0              85           64.0               78
# ...

# %%
df2.dropna(axis = 1)
# Out:
#     Sr No Gender   Reading_Score  Placement_Score  placement offer letter  \
# 0       1      M              78               60                       1
# 1       2      F              85               96                       3
# 2       3      M              77               84                       2
# 3       4      F              85               79                       2
# 4       5      F              80               84                       2
# 5       6      M              90              101                       1
# 6       7      M              82               94                       3
# 7       8      F              84               88                       3
# 8       9      M              75               92                       3
# 9      10      F              83               75                       2
# 10     11      F              85               78                       2
# 11     12      M              89               92                       3
# ...

# %%
new_data = df2.dropna(axis = 0, how ='any')
new_data
# Out:
#     Sr No Gender  Math_Score   Reading_Score  Writing_Score  Placement_Score  \
# 1       2      F        64.0              85           69.0               96
# 2       3      M        73.0              77           66.0               84
# 3       4      F        80.0              85           62.0               79
# 4       5      F        61.0              80           63.0               84
# 5       6      M        99.0              90           80.0              101
# 6       7      M        66.0              82           64.0               94
# 7       8      F        64.0              84           65.0               88
# 8       9      M        66.0              75           68.0               92
# 9      10      F        65.0              83           70.0               75
# 10     11      F        61.0              85           64.0               78
# 11     12      M        78.0              89           70.0               92
# ...

# %%
#BoxPloat:

# %%
import pandas as pd
import numpy as np
df3=pd.read_csv("/content/StudentsPerformance2.csv")
df3
# Out:
#     Sr No Gender  Math_Score   Reading_Score  Writing_Score  Placement_Score  \
# 0       1      M         NaN              78            NaN               60
# 1       2      F        64.0              85           69.0               96
# 2       3      M        73.0              77           66.0               84
# 3       4      F        80.0              85           62.0               79
# 4       5      F        61.0              80           63.0               84
# 5       6      M        99.0              90           80.0              101
# 6       7      M        66.0              82           64.0               94
# 7       8      F        64.0              84           65.0               88
# 8       9      M        66.0              75           68.0               92
# 9      10      F        65.0              83           70.0               75
# 10     11      F        61.0              85           64.0               78
# ...

# %%
col = ['Math_Score', ' Reading_Score' , 'Writing_Score','Placement_Score']
df3.boxplot(col)
# Out:
# <Axes: >

# %%
print(np.where(df['Math_Score']>90))
print(np.where(df[' Reading_Score']<25))
print(np.where(df['Writing_Score']<30))
# Out:
# (array([5]),)
# (array([], dtype=int64),)
# (array([], dtype=int64),)

# %%
import matplotlib.pyplot as plt
df3['Math_Score'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df3['log_math'] = np.log10(df['Math_Score'])

# %%
df3
# Out:
#     Sr No Gender  Math_Score   Reading_Score  Writing_Score  Placement_Score  \
# 0       1      M         NaN              78            NaN               60
# 1       2      F        64.0              85           69.0               96
# 2       3      M        73.0              77           66.0               84
# 3       4      F        80.0              85           62.0               79
# 4       5      F        61.0              80           63.0               84
# 5       6      M        99.0              90           80.0              101
# 6       7      M        66.0              82           64.0               94
# 7       8      F        64.0              84           65.0               88
# 8       9      M        66.0              75           68.0               92
# 9      10      F        65.0              83           70.0               75
# 10     11      F        61.0              85           64.0               78
# ...

# %%
df3['log_math'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
mean = df['Math_Score'].mean()
std_dev = df['Math_Score'].std()

# Calculate Z-scores for 'math score'
df['Math_Score'] = (df['Math_Score'] - mean) / std_dev

# %%
df
# Out:
#     Sr No Gender    Math_Score   Reading_Score  Writing_Score  \
# 0       1      M -1.776093e-15              78      65.689655
# 1       2      F -7.929856e-01              85      69.000000
# 2       3      M  3.318472e-01              77      66.000000
# 3       4      F  1.206717e+00              85      62.000000
# 4       5      F -1.167930e+00              80      63.000000
# 5       6      M  3.581364e+00              90      80.000000
# 6       7      M -5.430227e-01              82      64.000000
# 7       8      F -7.929856e-01              84      65.000000
# 8       9      M -5.430227e-01              75      68.000000
# 9      10      F -6.680042e-01              83      70.000000
# 10     11      F -1.167930e+00              85      64.000000
# 11     12      M  9.567544e-01              89      70.000000
# 12     13      M  8.317729e-01              81      66.000000
# 13     14      F  9.567544e-01              89      60.000000
# ...
