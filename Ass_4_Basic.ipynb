# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/Ass4.csv')

# %%
df.head( 10 )
# Out:
#    Sr no.  Percentage in Grade 10  Salary
# 0       1                   62.00  270000
# 1       2                   76.33  200000
# 2       3                   72.00  240000
# 3       4                   60.00  250000
# 4       5                   61.00  180000
# 5       6                   55.00  300000
# 6       7                   70.00  260000
# 7       8                   68.00  235000
# 8       9                   82.80  425000
# 9      10                   59.00  240000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Sr no.                  50 non-null     int64
#  1   Percentage in Grade 10  50 non-null     float64
#  2   Salary                  50 non-null     int64
# dtypes: float64(1), int64(2)
# memory usage: 1.3 KB

# %%
import statsmodels.api as sm
X = sm.add_constant(df['Percentage in Grade 10' ])
X.head(5)
# Out:
#    const  Percentage in Grade 10
# 0    1.0                   62.00
# 1    1.0                   76.33
# 2    1.0                   72.00
# 3    1.0                   60.00
# 4    1.0                   61.00

# %%
Y = df['Salary']
Y
# Out:
# 0     270000
# 1     200000
# 2     240000
# 3     250000
# 4     180000
# 5     300000
# 6     260000
# 7     235000
# 8     425000
# 9     240000
# 10    250000
# 11    180000
# 12    428000
# 13    450000
# 14    300000
# 15    240000
# 16    252000
# 17    280000
# 18    231000
# 19    224000
# 20    120000
# 21    260000
# 22    300000
# 23    120000
# 24    120000
# 25    250000
# 26    180000
# 27    218000
# 28    360000
# 29    150000
# 30    250000
# 31    200000
# 32    300000
# 33    330000
# 34    265000
# 35    340000
# 36    177600
# 37    236000
# 38    265000
# 39    200000
# 40    393000
# 41    360000
# 42    300000
# 43    250000
# 44    360000
# 45    180000
# 46    180000
# 47    270000
# 48    240000
# 49    300000
# Name: Salary, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
train_X, test_X, train_y, test_y = train_test_split( X,Y,train_size = 0.8,random_state = 100 )

# %%
mba_salary_lm = sm.OLS( train_y, train_X ).fit()

# %%
print( mba_salary_lm.params )
# Out:
# const                     30587.285652
# Percentage in Grade 10     3560.587383
# dtype: float64
